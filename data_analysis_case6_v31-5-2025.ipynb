# %%
#IMPORT LIABARIES
import pandas as pd
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
import os
from sklearn.decomposition import PCA
# Out:
# c:\Users\MK699GC\OneDrive - EY\Documents\EMAS\Case 6

# %%
#CHECK PATH, SET TO CORRECT PATH:
print(os.getcwd())
os.chdir("C:/Users/MK699GC/OneDrive - EY/Documents/EMAS\Case 6/interest_rates/data")

# %%
#LOADING IN DATA:
def load_term_structures(pattern, prefix):
    """
    Laad CSV bestanden volgens het glob pattern,
    voeg prefix toe aan kolomnamen (bijv. 'daily' of 'monthly')
    """
    files = glob.glob(pattern)
    dataframes = []

    print(f"Loading files with pattern '{pattern}'")
    for file in files:
        match = re.search(r'R(\d{2})XX', file)
        if not match:
            print(f"Term length not found in filename: {file}, skipping")
            continue
        term_length = match.group(1)

        df = pd.read_csv(file, skiprows=9, header=None, usecols=[0, 1])
        df.columns = ['years', f'{prefix}_data_term_{term_length}']
        dataframes.append(df)

    if not dataframes:
        print(f"No files loaded for pattern {pattern}")
        return None

    merged_df = dataframes[0]
    for df in dataframes[1:]:
        merged_df = pd.merge(merged_df, df, on='years', how='outer')

    merged_df = merged_df.sort_values(by='years').reset_index(drop=True)

    # Vervang '.' door NaN en converteer naar numeriek
    term_cols = [col for col in merged_df.columns if col.startswith(f'{prefix}_data_term_')]
    for col in term_cols:
        merged_df[col] = merged_df[col].replace('.', np.nan)
        merged_df[col] = pd.to_numeric(merged_df[col], errors='coerce')

    return merged_df

# Daily data laden
daily_df = load_term_structures('daily-term-structure-spot-interest-rate-R*XX.csv', 'daily')

# Monthly data laden
monthly_df = load_term_structures('monthly-term-structure-spot-interest-rate-R*XX.csv', 'monthly')

print("Daily data sample:")
print(daily_df.head() if daily_df is not None else "No daily data loaded")

print("\nMonthly data sample:")
print(monthly_df.head() if monthly_df is not None else "No monthly data loaded")
# Out:
# Loading files with pattern 'daily-term-structure-spot-interest-rate-R*XX.csv'
# Loading files with pattern 'monthly-term-structure-spot-interest-rate-R*XX.csv'
# Daily data sample:
#         years  daily_data_term_01  daily_data_term_02  daily_data_term_03  \
# 0  1997-08-01                 NaN                 NaN                 NaN
# 1  1997-08-02                 NaN                 NaN                 NaN
# 2  1997-08-03                 NaN                 NaN                 NaN
# 3  1997-08-04                 NaN                 NaN                 NaN
# 4  1997-08-05                 NaN                 NaN                 NaN
#
#    daily_data_term_04  daily_data_term_05  daily_data_term_06  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    daily_data_term_07  daily_data_term_08  daily_data_term_09  ...  \
# 0                 NaN                 NaN                 NaN  ...
# 1                 NaN                 NaN                 NaN  ...
# 2                 NaN                 NaN                 NaN  ...
# 3                 NaN                 NaN                 NaN  ...
# 4                 NaN                 NaN                 NaN  ...
#
#    daily_data_term_21  daily_data_term_22  daily_data_term_23  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    daily_data_term_24  daily_data_term_25  daily_data_term_26  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    daily_data_term_27  daily_data_term_28  daily_data_term_29  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    daily_data_term_30
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 31 columns]
#
# Monthly data sample:
#      years  monthly_data_term_01  monthly_data_term_02  monthly_data_term_03  \
# 0  1972-09                  6.70                  6.26                  6.92
# 1  1972-10                  7.04                  7.68                  7.96
# 2  1972-11                  9.09                  7.88                  7.99
# 3  1972-12                  6.92                  8.07                  8.26
# 4  1973-01                  6.42                  7.32                  7.87
#
#    monthly_data_term_04  monthly_data_term_05  monthly_data_term_06  \
# 0                  7.32                  7.58                  7.74
# 1                  8.10                  8.19                  8.24
# 2                  8.16                  8.29                  8.37
# 3                  8.30                  8.34                  8.41
# 4                  8.16                  8.33                  8.45
#
#    monthly_data_term_07  monthly_data_term_08  monthly_data_term_09  ...  \
# 0                  7.86                  7.95                  8.02  ...
# 1                  8.29                  8.32                  8.34  ...
# 2                  8.43                  8.48                  8.52  ...
# 3                  8.50                  8.59                  8.66  ...
# 4                  8.55                  8.65                  8.74  ...
#
#    monthly_data_term_21  monthly_data_term_22  monthly_data_term_23  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    monthly_data_term_24  monthly_data_term_25  monthly_data_term_26  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    monthly_data_term_27  monthly_data_term_28  monthly_data_term_29  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    monthly_data_term_30
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 31 columns]

# %%
#PLOT MONTHLY TERM STRUCTURE

monthly_df['years'] = pd.to_datetime(monthly_df['years'], errors='coerce')

plt.figure(figsize=(12, 8))

monthly_cols = sorted([col for col in monthly_df.columns if col.startswith('monthly_data_term_')])

for col in monthly_cols:
    label = col.replace('monthly_data_term_', '')  # Alleen het jaarnummer
    plt.plot(monthly_df['years'], monthly_df[col], label=label, alpha=0.7)

plt.title('Monthly Interest Rates for different maturities')
plt.xlabel('Date')
plt.ylabel('Interest Rate')

# Stel de x-as formatter en locator in voor datums
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(base=5))  # elke 5 jaar een tick
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.legend(loc='upper right', fontsize='small', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\4172256936.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   monthly_df['years'] = pd.to_datetime(monthly_df['years'], errors='coerce')

# %%
# PLOT DAILY TERM STRUCTURE

daily_df['years'] = pd.to_datetime(daily_df['years'], errors='coerce')

plt.figure(figsize=(12, 8))

daily_cols = sorted([col for col in daily_df.columns if col.startswith('daily_data_term_')])

for col in daily_cols:
    label = col.replace('daily_data_term_', '')  # Alleen het jaarnummer
    plt.plot(daily_df['years'], daily_df[col], label=label, alpha=0.7)

plt.title('Daily Interest Rates for different maturities')
plt.xlabel('Date')
plt.ylabel('Interest Rate')

# Stel de x-as formatter en locator in voor datums
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(base=5))  # elke 5 jaar een tick
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.legend(loc='upper right', fontsize='small', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# DESCRIPTIVE STATISTICS
def descriptive_stats(df):
    import re
    import numpy as np
    import pandas as pd

    # Sluit kolommen uit die met 'year' of 'Year' beginnen
    to_drop = [col for col in df.columns if col.lower().startswith('year')]
    data_cols = df.columns.drop(to_drop)

    # Statistieken opvragen
    stats = df[data_cols].describe().T
    stats['missing_pct'] = df[data_cols].isna().mean() * 100

    # Startjaar bepalen
    start_years = {}
    year_col = next((c for c in df.columns if c.lower().startswith('year')), None)
    for col in data_cols:
        first_valid_idx = df[col].first_valid_index()
        if first_valid_idx is not None and year_col is not None:
            start_year = df.loc[first_valid_idx, year_col].year
        else:
            start_year = np.nan
        start_years[col] = start_year

    stats['Start Year'] = pd.Series(start_years)

    # Zet kolomnamen (zoals 'daily_01') in een kolom om maturity te extraheren
    stats['Column Name'] = stats.index

    # Extract maturity-nummer uit kolomnaam
    stats['Maturity'] = stats['Column Name'].str.extract(r'(\d+)$')[0].astype(int)

    # Hernoemen van kolommen
    stats = stats.rename(columns={
        'count': 'Count',
        'mean': 'Mean',
        '50%': 'Median',
        'std': 'Std',
        'min': 'Min',
        'max': 'Max',
        'missing_pct': 'Missing %'
    })

    # Kolommen ordenen
    stats = stats[['Maturity', 'Count', 'Mean', 'Median', 'Std', 'Min', 'Max', 'Missing %', 'Start Year']]

    # Sorteren op Maturity
    stats = stats.sort_values('Maturity').reset_index(drop=True)

    # ✅ Index starten bij 1
    stats.index = stats.index + 1

    # Afronden
    stats = stats.round(2)

    return stats


def style_stats_table_clean(stats_df, title):
    styles = [
        {'selector': 'caption',
         'props': [('caption-side', 'top'), 
                   ('text-align', 'center'),
                   ('font-size', '18px'), 
                   ('font-weight', 'bold'),
                   ('padding', '10px 0')]},
        {'selector': 'th',
         'props': [('background-color', '#e1e1e1'), 
                   ('color', '#333'),
                   ('text-align', 'center'),
                   ('font-weight', '600'),
                   ('border-bottom', '1px solid #ccc'),
                   ('padding', '6px 8px')]},
        {'selector': 'td',
         'props': [('text-align', 'right'),
                   ('padding', '6px 8px'),
                   ('border-bottom', '1px solid #eee')]},
        {'selector': 'tbody tr:hover',
         'props': [('background-color', '#f5f5f5')]},
    ]
    
    return (stats_df.style
            .set_caption(title)
            .set_table_styles(styles)
            .format({
                'Count': '{:,.0f}',
                'Mean': '{:.2f}',
                'Median': '{:.2f}',
                'Std': '{:.2f}',
                'Min': '{:.2f}',
                'Max': '{:.2f}',
                'Missing %': '{:.1f}%',
                'Start Year': '{:.0f}'
            }))

# Gebruik:
daily_stats = descriptive_stats(daily_df)
monthly_stats = descriptive_stats(monthly_df)

display(style_stats_table_clean(daily_stats, "Descriptive Statistics Daily Data"))
display(style_stats_table_clean(monthly_stats, "Descriptive Statistics Monthly Data"))

daily_stats.to_excel('daily_stats.xlsx')
monthly_stats.to_excel('monthly_stats.xlsx')
# Out:
# <style type="text/css">
# #T_02613 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 18px;
#   font-weight: bold;
#   padding: 10px 0;
# }
# #T_02613 th {
#   background-color: #e1e1e1;
#   color: #333;
#   text-align: center;
#   font-weight: 600;
#   border-bottom: 1px solid #ccc;
#   padding: 6px 8px;
# }
# #T_02613 td {
#   text-align: right;
#   padding: 6px 8px;
#   border-bottom: 1px solid #eee;
# }
# #T_02613 tbody tr:hover {
#   background-color: #f5f5f5;
# }
# </style>
# <table id="T_02613">
#   <caption>Descriptive Statistics Daily Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02613_level0_col0" class="col_heading level0 col0" >Maturity</th>
#       <th id="T_02613_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_02613_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_02613_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_02613_level0_col4" class="col_heading level0 col4" >Std</th>
#       <th id="T_02613_level0_col5" class="col_heading level0 col5" >Min</th>
#       <th id="T_02613_level0_col6" class="col_heading level0 col6" >Max</th>
#       <th id="T_02613_level0_col7" class="col_heading level0 col7" >Missing %</th>
#       <th id="T_02613_level0_col8" class="col_heading level0 col8" >Start Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02613_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_02613_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_02613_row0_col1" class="data row0 col1" >7,048</td>
#       <td id="T_02613_row0_col2" class="data row0 col2" >1.56</td>
#       <td id="T_02613_row0_col3" class="data row0 col3" >1.81</td>
#       <td id="T_02613_row0_col4" class="data row0 col4" >1.84</td>
#       <td id="T_02613_row0_col5" class="data row0 col5" >-0.97</td>
#       <td id="T_02613_row0_col6" class="data row0 col6" >5.23</td>
#       <td id="T_02613_row0_col7" class="data row0 col7" >30.6%</td>
#       <td id="T_02613_row0_col8" class="data row0 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_02613_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_02613_row1_col1" class="data row1 col1" >7,048</td>
#       <td id="T_02613_row1_col2" class="data row1 col2" >1.66</td>
#       <td id="T_02613_row1_col3" class="data row1 col3" >1.89</td>
#       <td id="T_02613_row1_col4" class="data row1 col4" >1.86</td>
#       <td id="T_02613_row1_col5" class="data row1 col5" >-1.02</td>
#       <td id="T_02613_row1_col6" class="data row1 col6" >5.32</td>
#       <td id="T_02613_row1_col7" class="data row1 col7" >30.6%</td>
#       <td id="T_02613_row1_col8" class="data row1 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_02613_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_02613_row2_col1" class="data row2 col1" >7,048</td>
#       <td id="T_02613_row2_col2" class="data row2 col2" >1.78</td>
#       <td id="T_02613_row2_col3" class="data row2 col3" >1.99</td>
#       <td id="T_02613_row2_col4" class="data row2 col4" >1.89</td>
#       <td id="T_02613_row2_col5" class="data row2 col5" >-1.02</td>
#       <td id="T_02613_row2_col6" class="data row2 col6" >5.33</td>
#       <td id="T_02613_row2_col7" class="data row2 col7" >30.6%</td>
#       <td id="T_02613_row2_col8" class="data row2 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_02613_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_02613_row3_col1" class="data row3 col1" >7,048</td>
#       <td id="T_02613_row3_col2" class="data row3 col2" >1.91</td>
#       <td id="T_02613_row3_col3" class="data row3 col3" >2.17</td>
#       <td id="T_02613_row3_col4" class="data row3 col4" >1.90</td>
#       <td id="T_02613_row3_col5" class="data row3 col5" >-1.00</td>
#       <td id="T_02613_row3_col6" class="data row3 col6" >5.35</td>
#       <td id="T_02613_row3_col7" class="data row3 col7" >30.6%</td>
#       <td id="T_02613_row3_col8" class="data row3 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_02613_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_02613_row4_col1" class="data row4 col1" >7,048</td>
#       <td id="T_02613_row4_col2" class="data row4 col2" >2.05</td>
#       <td id="T_02613_row4_col3" class="data row4 col3" >2.32</td>
#       <td id="T_02613_row4_col4" class="data row4 col4" >1.91</td>
#       <td id="T_02613_row4_col5" class="data row4 col5" >-0.98</td>
#       <td id="T_02613_row4_col6" class="data row4 col6" >5.42</td>
#       <td id="T_02613_row4_col7" class="data row4 col7" >30.6%</td>
#       <td id="T_02613_row4_col8" class="data row4 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_02613_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_02613_row5_col1" class="data row5 col1" >7,048</td>
#       <td id="T_02613_row5_col2" class="data row5 col2" >2.18</td>
#       <td id="T_02613_row5_col3" class="data row5 col3" >2.43</td>
#       <td id="T_02613_row5_col4" class="data row5 col4" >1.91</td>
#       <td id="T_02613_row5_col5" class="data row5 col5" >-0.95</td>
#       <td id="T_02613_row5_col6" class="data row5 col6" >5.48</td>
#       <td id="T_02613_row5_col7" class="data row5 col7" >30.6%</td>
#       <td id="T_02613_row5_col8" class="data row5 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_02613_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_02613_row6_col1" class="data row6 col1" >7,048</td>
#       <td id="T_02613_row6_col2" class="data row6 col2" >2.31</td>
#       <td id="T_02613_row6_col3" class="data row6 col3" >2.48</td>
#       <td id="T_02613_row6_col4" class="data row6 col4" >1.91</td>
#       <td id="T_02613_row6_col5" class="data row6 col5" >-0.93</td>
#       <td id="T_02613_row6_col6" class="data row6 col6" >5.61</td>
#       <td id="T_02613_row6_col7" class="data row6 col7" >30.6%</td>
#       <td id="T_02613_row6_col8" class="data row6 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_02613_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_02613_row7_col1" class="data row7 col1" >7,048</td>
#       <td id="T_02613_row7_col2" class="data row7 col2" >2.43</td>
#       <td id="T_02613_row7_col3" class="data row7 col3" >2.55</td>
#       <td id="T_02613_row7_col4" class="data row7 col4" >1.91</td>
#       <td id="T_02613_row7_col5" class="data row7 col5" >-0.91</td>
#       <td id="T_02613_row7_col6" class="data row7 col6" >5.73</td>
#       <td id="T_02613_row7_col7" class="data row7 col7" >30.6%</td>
#       <td id="T_02613_row7_col8" class="data row7 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_02613_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_02613_row8_col1" class="data row8 col1" >7,048</td>
#       <td id="T_02613_row8_col2" class="data row8 col2" >2.53</td>
#       <td id="T_02613_row8_col3" class="data row8 col3" >2.66</td>
#       <td id="T_02613_row8_col4" class="data row8 col4" >1.90</td>
#       <td id="T_02613_row8_col5" class="data row8 col5" >-0.88</td>
#       <td id="T_02613_row8_col6" class="data row8 col6" >5.84</td>
#       <td id="T_02613_row8_col7" class="data row8 col7" >30.6%</td>
#       <td id="T_02613_row8_col8" class="data row8 col8" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_02613_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_02613_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_02613_row9_col1" class="data row9 col1" >7,048</td>
#       <td id="T_02613_row9_col2" class="data row9 col2" >2.63</td>
#       <td id="T_02613_row9_col3" class="data row9 col3" >2.76</td>
#       <td id="T_02613_row9_col
# <style type="text/css">
# #T_a3f11 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 18px;
#   font-weight: bold;
#   padding: 10px 0;
# }
# #T_a3f11 th {
#   background-color: #e1e1e1;
#   color: #333;
#   text-align: center;
#   font-weight: 600;
#   border-bottom: 1px solid #ccc;
#   padding: 6px 8px;
# }
# #T_a3f11 td {
#   text-align: right;
#   padding: 6px 8px;
#   border-bottom: 1px solid #eee;
# }
# #T_a3f11 tbody tr:hover {
#   background-color: #f5f5f5;
# }
# </style>
# <table id="T_a3f11">
#   <caption>Descriptive Statistics Monthly Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3f11_level0_col0" class="col_heading level0 col0" >Maturity</th>
#       <th id="T_a3f11_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_a3f11_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_a3f11_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_a3f11_level0_col4" class="col_heading level0 col4" >Std</th>
#       <th id="T_a3f11_level0_col5" class="col_heading level0 col5" >Min</th>
#       <th id="T_a3f11_level0_col6" class="col_heading level0 col6" >Max</th>
#       <th id="T_a3f11_level0_col7" class="col_heading level0 col7" >Missing %</th>
#       <th id="T_a3f11_level0_col8" class="col_heading level0 col8" >Start Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3f11_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a3f11_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a3f11_row0_col1" class="data row0 col1" >632</td>
#       <td id="T_a3f11_row0_col2" class="data row0 col2" >3.91</td>
#       <td id="T_a3f11_row0_col3" class="data row0 col3" >3.80</td>
#       <td id="T_a3f11_row0_col4" class="data row0 col4" >3.22</td>
#       <td id="T_a3f11_row0_col5" class="data row0 col5" >-0.92</td>
#       <td id="T_a3f11_row0_col6" class="data row0 col6" >13.17</td>
#       <td id="T_a3f11_row0_col7" class="data row0 col7" >0.0%</td>
#       <td id="T_a3f11_row0_col8" class="data row0 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a3f11_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a3f11_row1_col1" class="data row1 col1" >632</td>
#       <td id="T_a3f11_row1_col2" class="data row1 col2" >4.09</td>
#       <td id="T_a3f11_row1_col3" class="data row1 col3" >4.08</td>
#       <td id="T_a3f11_row1_col4" class="data row1 col4" >3.21</td>
#       <td id="T_a3f11_row1_col5" class="data row1 col5" >-0.92</td>
#       <td id="T_a3f11_row1_col6" class="data row1 col6" >12.33</td>
#       <td id="T_a3f11_row1_col7" class="data row1 col7" >0.0%</td>
#       <td id="T_a3f11_row1_col8" class="data row1 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a3f11_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a3f11_row2_col1" class="data row2 col1" >632</td>
#       <td id="T_a3f11_row2_col2" class="data row2 col2" >4.27</td>
#       <td id="T_a3f11_row2_col3" class="data row2 col3" >4.38</td>
#       <td id="T_a3f11_row2_col4" class="data row2 col4" >3.21</td>
#       <td id="T_a3f11_row2_col5" class="data row2 col5" >-0.95</td>
#       <td id="T_a3f11_row2_col6" class="data row2 col6" >12.00</td>
#       <td id="T_a3f11_row2_col7" class="data row2 col7" >0.0%</td>
#       <td id="T_a3f11_row2_col8" class="data row2 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a3f11_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a3f11_row3_col1" class="data row3 col1" >632</td>
#       <td id="T_a3f11_row3_col2" class="data row3 col2" >4.44</td>
#       <td id="T_a3f11_row3_col3" class="data row3 col3" >4.62</td>
#       <td id="T_a3f11_row3_col4" class="data row3 col4" >3.21</td>
#       <td id="T_a3f11_row3_col5" class="data row3 col5" >-0.95</td>
#       <td id="T_a3f11_row3_col6" class="data row3 col6" >11.76</td>
#       <td id="T_a3f11_row3_col7" class="data row3 col7" >0.0%</td>
#       <td id="T_a3f11_row3_col8" class="data row3 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a3f11_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a3f11_row4_col1" class="data row4 col1" >632</td>
#       <td id="T_a3f11_row4_col2" class="data row4 col2" >4.58</td>
#       <td id="T_a3f11_row4_col3" class="data row4 col3" >4.81</td>
#       <td id="T_a3f11_row4_col4" class="data row4 col4" >3.19</td>
#       <td id="T_a3f11_row4_col5" class="data row4 col5" >-0.93</td>
#       <td id="T_a3f11_row4_col6" class="data row4 col6" >11.49</td>
#       <td id="T_a3f11_row4_col7" class="data row4 col7" >0.0%</td>
#       <td id="T_a3f11_row4_col8" class="data row4 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a3f11_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a3f11_row5_col1" class="data row5 col1" >632</td>
#       <td id="T_a3f11_row5_col2" class="data row5 col2" >4.70</td>
#       <td id="T_a3f11_row5_col3" class="data row5 col3" >5.01</td>
#       <td id="T_a3f11_row5_col4" class="data row5 col4" >3.17</td>
#       <td id="T_a3f11_row5_col5" class="data row5 col5" >-0.90</td>
#       <td id="T_a3f11_row5_col6" class="data row5 col6" >11.20</td>
#       <td id="T_a3f11_row5_col7" class="data row5 col7" >0.0%</td>
#       <td id="T_a3f11_row5_col8" class="data row5 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a3f11_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a3f11_row6_col1" class="data row6 col1" >632</td>
#       <td id="T_a3f11_row6_col2" class="data row6 col2" >4.81</td>
#       <td id="T_a3f11_row6_col3" class="data row6 col3" >5.14</td>
#       <td id="T_a3f11_row6_col4" class="data row6 col4" >3.14</td>
#       <td id="T_a3f11_row6_col5" class="data row6 col5" >-0.85</td>
#       <td id="T_a3f11_row6_col6" class="data row6 col6" >10.90</td>
#       <td id="T_a3f11_row6_col7" class="data row6 col7" >0.0%</td>
#       <td id="T_a3f11_row6_col8" class="data row6 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_a3f11_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a3f11_row7_col1" class="data row7 col1" >632</td>
#       <td id="T_a3f11_row7_col2" class="data row7 col2" >4.91</td>
#       <td id="T_a3f11_row7_col3" class="data row7 col3" >5.23</td>
#       <td id="T_a3f11_row7_col4" class="data row7 col4" >3.11</td>
#       <td id="T_a3f11_row7_col5" class="data row7 col5" >-0.80</td>
#       <td id="T_a3f11_row7_col6" class="data row7 col6" >10.99</td>
#       <td id="T_a3f11_row7_col7" class="data row7 col7" >0.0%</td>
#       <td id="T_a3f11_row7_col8" class="data row7 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_a3f11_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_a3f11_row8_col1" class="data row8 col1" >632</td>
#       <td id="T_a3f11_row8_col2" class="data row8 col2" >4.99</td>
#       <td id="T_a3f11_row8_col3" class="data row8 col3" >5.28</td>
#       <td id="T_a3f11_row8_col4" class="data row8 col4" >3.07</td>
#       <td id="T_a3f11_row8_col5" class="data row8 col5" >-0.76</td>
#       <td id="T_a3f11_row8_col6" class="data row8 col6" >11.16</td>
#       <td id="T_a3f11_row8_col7" class="data row8 col7" >0.0%</td>
#       <td id="T_a3f11_row8_col8" class="data row8 col8" >1972</td>
#     </tr>
#     <tr>
#       <th id="T_a3f11_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_a3f11_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_a3f11_row9_col1" class="data row9 col1" >632</td>
#       <td id="T_a3f11_row9_col2" class="data row9 col2" >5.06</td>
#       <td id="T_a3f11_row9_col3" class="data row9 col3" >5.33</td>
#       <td id="T_a3f11_row9_col4" class="data row
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\4235130637.py:103: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   daily_stats.to_excel('daily_stats.xlsx')
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\4235130637.py:104: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   monthly_stats.to_excel('monthly_stats.xlsx')

# %%
#CORRELATION MATRIX
def plot_correlation_heatmap_annotated(df, title):
    term_cols = sorted([col for col in df.columns if 'data_term_' in col])
    corr = df[term_cols].corr()

    plt.figure(figsize=(18,16))
    ax = sns.heatmap(
        corr,
        cmap='vlag',
        center=0.9,
        vmin=0.8,
        vmax=1.0,
        square=True,
        annot=True,
        fmt=".2f",
        annot_kws={"size":7},
        linewidths=0.3,
        cbar_kws={"shrink": 0.6}
    )
    plt.title(title, fontsize=20)

    # Vervang de xticks en yticks labels door alleen het nummer (bijv. '1' in plaats van 'daily_data_term_01')
    new_labels = [col.split('_')[-1] for col in term_cols]  # pakt '01', '02', etc.
    new_labels = [str(int(label)) for label in new_labels]  # converteert '01' -> '1' als string

    ax.set_xticklabels(new_labels, rotation=90, fontsize=8)
    ax.set_yticklabels(new_labels, fontsize=8)
    
    plt.tight_layout()
    plt.show()

    return corr

# Plot en sla de correlatiematrices op
daily_corr = plot_correlation_heatmap_annotated(daily_df, 'Correlation Heatmap for different maturities - Daily Data')
monthly_corr = plot_correlation_heatmap_annotated(monthly_df, 'Correlation Heatmap for different maturities - Monthly Data')

# Toon de correlatiematrices als tabel
print("Correlation matrix - Daily Data:")
print(daily_corr.round(3))

print("\nCorrelation matrix - Monthly Data:")
print(monthly_corr.round(3))
# Out:
# Correlation matrix - Daily Data:
#                     daily_data_term_01  daily_data_term_02  \
# daily_data_term_01               1.000               0.993
# daily_data_term_02               0.993               1.000
# daily_data_term_03               0.981               0.996
# daily_data_term_04               0.967               0.989
# daily_data_term_05               0.953               0.979
# daily_data_term_06               0.940               0.970
# daily_data_term_07               0.927               0.960
# daily_data_term_08               0.916               0.950
# daily_data_term_09               0.905               0.941
# daily_data_term_10               0.896               0.933
# daily_data_term_11               0.887               0.925
# daily_data_term_12               0.879               0.918
# daily_data_term_13               0.872               0.912
# daily_data_term_14               0.866               0.906
# daily_data_term_15               0.861               0.902
# daily_data_term_16               0.857               0.898
# daily_data_term_17               0.853               0.895
# daily_data_term_18               0.850               0.892
# daily_data_term_19               0.848               0.890
# daily_data_term_20               0.846               0.888
# daily_data_term_21               0.820               0.866
# daily_data_term_22               0.819               0.865
# daily_data_term_23               0.818               0.864
# daily_data_term_24               0.818               0.864
# daily_data_term_25               0.818               0.864
# daily_data_term_26               0.818               0.865
# daily_data_term_27               0.819               0.865
# daily_data_term_28               0.819               0.865
# daily_data_term_29               0.820               0.866
# daily_data_term_30               0.821               0.867
#
#                     daily_data_term_03  daily_data_term_04  \
# daily_data_term_01               0.981               0.967
# daily_data_term_02               0.996               0.989
# daily_data_term_03               1.000               0.998
# daily_data_term_04               0.998               1.000
# daily_data_term_05               0.993               0.999
# daily_data_term_06               0.986               0.995
# daily_data_term_07               0.979               0.990
# daily_data_term_08               0.972               0.985
# daily_data_term_09               0.965               0.979
# daily_data_term_10               0.958               0.974
# daily_data_term_11               0.951               0.968
# daily_data_term_12               0.945               0.963
# daily_data_term_13               0.940               0.959
# daily_data_term_14               0.935               0.955
# daily_data_term_15               0.931               0.951
# daily_data_term_16               0.927               0.948
# daily_data_term_17               0.924               0.945
# daily_data_term_18               0.922               0.943
# daily_data_term_19               0.920               0.942
# daily_data_term_20               0.919               0.941
# daily_data_term_21               0.901               0.927
# daily_data_term_22               0.901               0.927
# daily_data_term_23               0.900               0.926
# daily_data_term_24               0.900               0.926
# daily_data_term_25               0.900               0.926
# daily_data_term_26               0.900               0.927
# daily_data_term_27               0.901               0.927
# daily_data_term_28               0.901               0.927
# daily_data_term_29               0.902               0.928
# daily_data_term_30               0.902               0.928
#
#                     daily_data_term_05  daily_data_term_06  \
# daily_data_term_01               0.953               0.940
# daily_data_term_02               0.979               0.970
# daily_data_term_03               0.993               0.986
# daily_data_term_04               0.999               0.995
# daily_data_term_05               1.000               0.999
# daily_data_term_06               0.999               1.000
# daily_data_term_07               0.996               0.999
# daily_data_term_08               0.993               0.997
# daily_data_term_09               0.989               0.994
# daily_data_term_10               0.984               0.991
# daily_data_term_11               0.980               0.988
# daily_data_term_12               0.976               0.985
# daily_data_term_13               0.972               0.981
# daily_data_term_14               0.968               0.978
# daily_data_term_15               0.965               0.976
# daily_data_term_16               0.963               0.974
# daily_data_term_17               0.960               0.972
# daily_data_term_18               0.959               0.970
# daily_data_term_19               0.957               0.969
# daily_data_term_20               0.956               0.968
# daily_data_term_21               0.947               0.961
# daily_data_term_22               0.946               0.960
# daily_data_term_23               0.946               0.960
# daily_data_term_24               0.946               0.960
# daily_data_term_25               0.946               0.960
# daily_data_term_26               0.946               0.960
# daily_data_term_27               0.946               0.960
# daily_data_term_28               0.946               0.960
# daily_data_term_29               0.946               0.960
# daily_data_term_30               0.947               0.960
#
#                     daily_data_term_07  daily_data_term_08  \
# daily_data_term_01               0.927               0.916
# daily_data_term_02               0.960               0.950
# daily_data_term_03               0.979               0.972
# daily_data_term_04               0.990               0.985
# daily_data_term_05               0.996               0.993
# daily_data_term_06               0.999               0.997
# daily_data_term_07               1.000               0.999
# daily_data_term_08               0.999               1.000
# daily_data_term_09               0.998               1.000
# daily_data_term_10               0.996               0.998
# daily_data_term_11               0.993               0.997
# daily_data_term_12               0.991               0.995
# daily_data_term_13               0.988               0.993
# daily_data_term_14               0.986               0.991
# daily_data_term_15               0.984               0.989
# daily_data_term_16               0.982               0.988
# daily_data_term_17               0.980               0.986
# daily_data_term_18               0.979               0.985
# daily_data_term_19               0.978               0.984
# daily_data_term_20               0.977               0.983
# daily_data_term_21               0.971               0.980
# daily_data_term_22               0.971               0.979
# daily_data_term_23               0.971               0.979
# daily_data_term_24               0.970               0.979
# daily_data_term_25               0.970               0.978
# daily_data_term_26               0.970               0.978
# daily_data_term_27               0.970               0.978
# daily_data_term_28               0.970               0.978
# daily_data_term_29               0.970               0.978
# daily_data_term_30               0.970               0.978
#
#                     daily_data_term_09  daily_data_term_10  ...  \
# daily_data_term_01               0.905               0.896  ...
# daily_data_term_02               0.941               0.933  ...
# daily_data_term_03               0.965               0.958  ...
# daily_data_term_04               0.979               0.974  ...
# daily_data_term_05               0.989               0.984  ...
# daily_data_term_06               0.994               0.991  ...
# daily_data_term_07               0.998               0.996  ...
# daily_data_term_08               1.000               0.998  ...
# daily_data_term_09               1.000               1.000  ...
# daily_data_term_10               1.000               1.000  ...
# daily_data_term_11               0.999               1.000  ...
# daily_data_term_12               0.997               0.999  ...
# daily_data_term_13               0.996               0.998  ...
# daily_data_term_14               0.995               0.997  ...
# daily_data_term_15               0.993               0.996  ...
# daily_data_term_16               0.992               0.995  ...
# daily_data_term_17               0.991               0.994  ...
# daily_data_term_18               0.990               0.993  ...
# daily_data_term_19               0.989               0.992  ...
# daily_data_term_20               0.988               0.992  ...
# daily_data_term_21               0.986               0.990  ...
# daily_data_term_22               0.985               0.989  ...
# daily_data_term_23               0.985               0.989  ...
# daily_data_term_24               0.984               0.989  ...
# daily_data_term_25               0.984               0.989  ...
# daily_data_term_26               0.984               0.988  ...
# daily_data_term_27               0.984               0.988  ...
# daily_data_term_28               0.984               0.988  ...
# daily_data_term_29               0.983               0.987  ...
# daily_data_term_30               0.983               0.987  ...
#
#                     daily_data_term_21  daily_data_term_22  \
# daily_data_term_01               0.820               0.819
# daily_data_term_02               0.866               0.865
# daily_data_term_03               0.901               0.901
# daily_data_term_04               0.927               0.927
# daily_data_term_05               0.947               0.946
# daily_data_term_06               0.961               0.960
# daily_data_term_07               0.971               0.971
# daily_data_term_08               0.980               0.979
# daily_data_term_09               0.986               0.985
# daily_data_term_10               0.990               0.989
# daily_data_term_11               0.993               0.993
# daily_data_term_12               0.995               0.995
# daily_data_term_13               0.997               0.997
# daily_data_term_14               0.998               0.998
# daily_data_term_15               0.999               0.998
# daily_data_term_16               0.999               0.999
# daily_data_term_17               1.000               0.999
# daily_data_term_18               1.000               1.000
# daily_data_term_19               1.000               1.000
# daily_data_term_20               1.000               1.000
# daily_data_term_21               1.000               1.000
# daily_data_term_22               1.000               1.000
# daily_data_term_23               1.000               1.000
# daily_data_term_24               1.000               1.000
# daily_data_term_25               1.000               1.000
# daily_data_term_26               0.999               0.999
# daily_data_term_27               0.999               0.999
# daily_data_term_28               0.998               0.999
# daily_data_term_29               0.998               0.998
# daily_data_term_30               0.997               0.998
#
#                     daily_data_term_23  daily_data_term_24  \
# daily_data_term_01               0.818               0.818
# daily_data_term_02               0.864               0.864
# daily_data_term_03               0.900               0.900
# daily_data_term_04               0.926               0.926
# daily_data_term_05               0.946               0.946
# daily_data_term_06               0.960               0.960
# daily_data_term_07               0.971               0.970
# daily_data_term_08               0.979               0.979
# daily_data_term_09               0.985               0.984
# daily_data_term_10               0.989               0.989
# daily_data_term_11               0.992               0.992
# daily_data_term_12               0.995               0.994
# daily_data_term_13               0.996               0.996
# daily_data_term_14               0.997               0.997
# daily_data_term_15               0.998               0.998
# daily_data_term_16               0.999               0.998
# daily_data_term_17               0.999               0.999
# daily_data_term_18               0.999               0.999
# daily_data_term_19               1.000               0.999
# daily_data_term_20               1.000               1.000
# daily_data_term_21               1.000               1.000
# daily_data_term_22               1.000               1.000
# daily_data_term_23               1.000               1.000
# daily_data_term_24               1.000               1.000
# daily_data_term_25               1.000               1.000
# daily_data_term_26               1.000               1.000
# daily_data_term_27               0.999               1.000
# daily_data_term_28               0.999               0.999
# daily_data_term_29               0.999               0.999
# daily_data_term_30               0.998               0.999
#
#                     daily_data_term_25  daily_data_term_26  \
# daily_data_term_01               0.818               0.818
# daily_data_term_02               0.864               0.865
# daily_data_term_03               0.900               0.900
# daily_data_term_04               0.926               0.927
# daily_data_term_05               0.946               0.946
# daily_data_term_06               0.960               0.960
# daily_data_term_07               0.970               0.970
# daily_data_term_08               0.978               0.978
# daily_data_term_09               0.984               0.984
# daily_data_term_10               0.989               0.988
# daily_data_term_11               0.992               0.991
# daily_data_term_12               0.994               0.994
# daily_data_term_13               0.995               0.995
# daily_data_term_14               0.997               0.996
# daily_data_term_15               0.997               0.997
# daily_data_term_16               0.998               0.997
# daily_data_term_17               0.998               0.998
# daily_data_term_18               0.999               0.998
# daily_data_term_19               0.999               0.999
# daily_data_term_20               0.999               0.999
# daily_data_term_21               1.000               0.999
# daily_data_term_22               1.000               0.999
# daily_data_term_23               1.000               1.000
# daily_data_term_24               1.000               1.000
# daily_data_term_25               1.000               1.000
# daily_data_term_26               1.000               1.000
# daily_data_term_27               1.000               1.000
# daily_data_term_28               1.000               1.000
# daily_data_term_29               0.999               1.000
# daily_data_term_30               0.999               0.999
#
#                     daily_data_term_27  daily_data_term_28  \
# daily_data_term_01               0.819               0.819
# daily_data_term_02               0.865               0.865
# daily_data_term_03               0.901               0.901
# daily_data_term_04               0.927               0.927
# daily_data_term_05               0.946               0.946
# daily_data_term_06               0.960               0.960
# daily_data_term_07               0.970               0.970
# daily_data_term_08               0.978               0.978
# daily_data_term_09               0.984               0.984
# daily_data_term_10               0.988               0.988
# daily_data_term_11               0.991               0.991
# daily_data_term_12               0.993               0.993
# daily_data_term_13               0.995               0.994
# daily_data_term_14               0.996               0.995
# daily_data_term_15               0.996               0.996
# daily_data_term_16               0.997               0.996
# daily_data_term_17               0.997               0.997
# daily_data_term_18               0.998               0.997
# daily_data_term_19               0.998               0.998
# daily_data_term_20               0.999               0.998
# daily_data_term_21               0.999               0.998
# daily_data_term_22               0.999               0.999
# daily_data_term_23               0.999               0.999
# daily_data_term_24               1.000               0.999
# daily_data_term_25               1.000               1.000
# daily_data_term_26               1.000               1.000
# daily_data_term_27               1.000               1.000
# daily_data_term_28               1.000               1.000
# daily_data_term_29               1.000               1.000
# daily_data_term_30               1.000               1.000
#
#                     daily_data_term_29  daily_data_term_30
# daily_data_term_01               0.820               0.821
# daily_data_term_02               0.866               0.867
# daily_data_term_03               0.902               0.902
# daily_data_term_04               0.928               0.928
# daily_data_term_05               0.946               0.947
# daily_data_term_06               0.960               0.960
# daily_data_term_07               0.970               0.970
# daily_data_term_08               0.978               0.978
# daily_data_term_09               0.983               0.983
# daily_data_term_10               0.987               0.987
# daily_data_term_11               0.990               0.990
# daily_data_term_12               0.992               0.992
# daily_data_term_13               0.993               0.993
# daily_data_term_14               0.994               0.994
# daily_data_term_15               0.995               0.994
# daily_data_term_16               0.996               0.995
# daily_data_term_17               0.996               0.995
# daily_data_term_18               0.997               0.996
# daily_data_term_19               0.997               0.996
# daily_data_term_20               0.997               0.997
# daily_data_term_21               0.998               0.997
# daily_data_term_22               0.998               0.998
# daily_data_term_23               0.999               0.998
# daily_data_term_24               0.999               0.999
# daily_data_term_25               0.999               0.999
# daily_data_term_26               1.000               0.999
# daily_data_term_27               1.000               1.000
# daily_data_term_28               1.000               1.000
# daily_data_term_29               1.000               1.000
# daily_data_term_30               1.000               1.000
#
# [30 rows x 30 columns]
#
# Correlation matrix - Monthly Data:
#                       monthly_data_term_01  monthly_data_term_02  \
# monthly_data_term_01                 1.000                 0.994
# monthly_data_term_02                 0.994                 1.000
# monthly_data_term_03                 0.984                 0.997
# monthly_data_term_04                 0.975                 0.992
# monthly_data_term_05                 0.965                 0.986
# monthly_data_term_06                 0.957                 0.980
# monthly_data_term_07                 0.950                 0.974
# monthly_data_term_08                 0.943                 0.968
# monthly_data_term_09                 0.936                 0.963
# monthly_data_term_10                 0.931                 0.958
# monthly_data_term_11                 0.917                 0.942
# monthly_data_term_12                 0.910                 0.937
# monthly_data_term_13                 0.905                 0.932
# monthly_data_term_14                 0.900                 0.927
# monthly_data_term_15                 0.895                 0.923
# monthly_data_term_16                 0.891                 0.919
# monthly_data_term_17                 0.887                 0.916
# monthly_data_term_18                 0.884                 0.913
# monthly_data_term_19                 0.881                 0.910
# monthly_data_term_20                 0.878                 0.908
# monthly_data_term_21                 0.832                 0.875
# monthly_data_term_22                 0.831                 0.874
# monthly_data_term_23                 0.831                 0.873
# monthly_data_term_24                 0.830                 0.873
# monthly_data_term_25                 0.830                 0.873
# monthly_data_term_26                 0.831                 0.874
# monthly_data_term_27                 0.831                 0.874
# monthly_data_term_28                 0.832                 0.875
# monthly_data_term_29                 0.832                 0.875
# monthly_data_term_30                 0.833                 0.876
#
#                       monthly_data_term_03  monthly_data_term_04  \
# monthly_data_term_01                 0.984                 0.975
# monthly_data_term_02                 0.997                 0.992
# monthly_data_term_03                 1.000                 0.998
# monthly_data_term_04                 0.998                 1.000
# monthly_data_term_05                 0.995                 0.999
# monthly_data_term_06                 0.991                 0.997
# monthly_data_term_07                 0.987                 0.994
# monthly_data_term_08                 0.983                 0.991
# monthly_data_term_09                 0.979                 0.988
# monthly_data_term_10                 0.975                 0.985
# monthly_data_term_11                 0.962                 0.976
# monthly_data_term_12                 0.957                 0.972
# monthly_data_term_13                 0.953                 0.968
# monthly_data_term_14                 0.949                 0.965
# monthly_data_term_15                 0.945                 0.962
# monthly_data_term_16                 0.942                 0.959
# monthly_data_term_17                 0.939                 0.957
# monthly_data_term_18                 0.937                 0.954
# monthly_data_term_19                 0.935                 0.952
# monthly_data_term_20                 0.932                 0.951
# monthly_data_term_21                 0.908                 0.932
# monthly_data_term_22                 0.907                 0.932
# monthly_data_term_23                 0.907                 0.931
# monthly_data_term_24                 0.907                 0.931
# monthly_data_term_25                 0.907                 0.931
# monthly_data_term_26                 0.907                 0.932
# monthly_data_term_27                 0.908                 0.932
# monthly_data_term_28                 0.908                 0.932
# monthly_data_term_29                 0.909                 0.933
# monthly_data_term_30                 0.909                 0.933
#
#                       monthly_data_term_05  monthly_data_term_06  \
# monthly_data_term_01                 0.965                 0.957
# monthly_data_term_02                 0.986                 0.980
# monthly_data_term_03                 0.995                 0.991
# monthly_data_term_04                 0.999                 0.997
# monthly_data_term_05                 1.000                 0.999
# monthly_data_term_06                 0.999                 1.000
# monthly_data_term_07                 0.998                 1.000
# monthly_data_term_08                 0.996                 0.998
# monthly_data_term_09                 0.994                 0.997
# monthly_data_term_10                 0.991                 0.995
# monthly_data_term_11                 0.985                 0.991
# monthly_data_term_12                 0.982                 0.989
# monthly_data_term_13                 0.979                 0.986
# monthly_data_term_14                 0.976                 0.984
# monthly_data_term_15                 0.973                 0.982
# monthly_data_term_16                 0.971                 0.980
# monthly_data_term_17                 0.969                 0.978
# monthly_data_term_18                 0.967                 0.976
# monthly_data_term_19                 0.965                 0.975
# monthly_data_term_20                 0.964                 0.973
# monthly_data_term_21                 0.950                 0.963
# monthly_data_term_22                 0.949                 0.963
# monthly_data_term_23                 0.949                 0.963
# monthly_data_term_24                 0.949                 0.962
# monthly_data_term_25                 0.949                 0.962
# monthly_data_term_26                 0.949                 0.962
# monthly_data_term_27                 0.950                 0.963
# monthly_data_term_28                 0.950                 0.963
# monthly_data_term_29                 0.950                 0.963
# monthly_data_term_30                 0.950                 0.963
#
#                       monthly_data_term_07  monthly_data_term_08  \
# monthly_data_term_01                 0.950                 0.943
# monthly_data_term_02                 0.974                 0.968
# monthly_data_term_03                 0.987                 0.983
# monthly_data_term_04                 0.994                 0.991
# monthly_data_term_05                 0.998                 0.996
# monthly_data_term_06                 1.000                 0.998
# monthly_data_term_07                 1.000                 1.000
# monthly_data_term_08                 1.000                 1.000
# monthly_data_term_09                 0.999                 1.000
# monthly_data_term_10                 0.998                 0.999
# monthly_data_term_11                 0.995                 0.998
# monthly_data_term_12                 0.993                 0.996
# monthly_data_term_13                 0.991                 0.995
# monthly_data_term_14                 0.989                 0.993
# monthly_data_term_15                 0.988                 0.992
# monthly_data_term_16                 0.986                 0.990
# monthly_data_term_17                 0.984                 0.989
# monthly_data_term_18                 0.983                 0.988
# monthly_data_term_19                 0.982                 0.987
# monthly_data_term_20                 0.980                 0.986
# monthly_data_term_21                 0.973                 0.981
# monthly_data_term_22                 0.973                 0.980
# monthly_data_term_23                 0.973                 0.980
# monthly_data_term_24                 0.972                 0.980
# monthly_data_term_25                 0.972                 0.980
# monthly_data_term_26                 0.972                 0.980
# monthly_data_term_27                 0.972                 0.980
# monthly_data_term_28                 0.972                 0.980
# monthly_data_term_29                 0.972                 0.980
# monthly_data_term_30                 0.973                 0.979
#
#                       monthly_data_term_09  monthly_data_term_10  ...  \
# monthly_data_term_01                 0.936                 0.931  ...
# monthly_data_term_02                 0.963                 0.958  ...
# monthly_data_term_03                 0.979                 0.975  ...
# monthly_data_term_04                 0.988                 0.985  ...
# monthly_data_term_05                 0.994                 0.991  ...
# monthly_data_term_06                 0.997                 0.995  ...
# monthly_data_term_07                 0.999                 0.998  ...
# monthly_data_term_08                 1.000                 0.999  ...
# monthly_data_term_09                 1.000                 1.000  ...
# monthly_data_term_10                 1.000                 1.000  ...
# monthly_data_term_11                 0.999                 1.000  ...
# monthly_data_term_12                 0.998                 0.999  ...
# monthly_data_term_13                 0.997                 0.999  ...
# monthly_data_term_14                 0.996                 0.998  ...
# monthly_data_term_15                 0.995                 0.997  ...
# monthly_data_term_16                 0.994                 0.996  ...
# monthly_data_term_17                 0.992                 0.995  ...
# monthly_data_term_18                 0.991                 0.994  ...
# monthly_data_term_19                 0.990                 0.993  ...
# monthly_data_term_20                 0.990                 0.992  ...
# monthly_data_term_21                 0.986                 0.991  ...
# monthly_data_term_22                 0.986                 0.990  ...
# monthly_data_term_23                 0.986                 0.990  ...
# monthly_data_term_24                 0.985                 0.990  ...
# monthly_data_term_25                 0.985                 0.989  ...
# monthly_data_term_26                 0.985                 0.989  ...
# monthly_data_term_27                 0.985                 0.989  ...
# monthly_data_term_28                 0.985                 0.989  ...
# monthly_data_term_29                 0.985                 0.988  ...
# monthly_data_term_30                 0.984                 0.988  ...
#
#                       monthly_data_term_21  monthly_data_term_22  \
# monthly_data_term_01                 0.832                 0.831
# monthly_data_term_02                 0.875                 0.874
# monthly_data_term_03                 0.908                 0.907
# monthly_data_term_04                 0.932                 0.932
# monthly_data_term_05                 0.950                 0.949
# monthly_data_term_06                 0.963                 0.963
# monthly_data_term_07                 0.973                 0.973
# monthly_data_term_08                 0.981                 0.980
# monthly_data_term_09                 0.986                 0.986
# monthly_data_term_10                 0.991                 0.990
# monthly_data_term_11                 0.994                 0.993
# monthly_data_term_12                 0.996                 0.995
# monthly_data_term_13                 0.997                 0.997
# monthly_data_term_14                 0.998                 0.998
# monthly_data_term_15                 0.999                 0.999
# monthly_data_term_16                 0.999                 0.999
# monthly_data_term_17                 1.000                 0.999
# monthly_data_term_18                 1.000                 1.000
# monthly_data_term_19                 1.000                 1.000
# monthly_data_term_20                 1.000                 1.000
# monthly_data_term_21                 1.000                 1.000
# monthly_data_term_22                 1.000                 1.000
# monthly_data_term_23                 1.000                 1.000
# monthly_data_term_24                 1.000                 1.000
# monthly_data_term_25                 1.000                 1.000
# monthly_data_term_26                 0.999                 1.000
# monthly_data_term_27                 0.999                 0.999
# monthly_data_term_28                 0.998                 0.999
# monthly_data_term_29                 0.998                 0.998
# monthly_data_term_30                 0.997                 0.998
#
#                       monthly_data_term_23  monthly_data_term_24  \
# monthly_data_term_01                 0.831                 0.830
# monthly_data_term_02                 0.873                 0.873
# monthly_data_term_03                 0.907                 0.907
# monthly_data_term_04                 0.931                 0.931
# monthly_data_term_05                 0.949                 0.949
# monthly_data_term_06                 0.963                 0.962
# monthly_data_term_07                 0.973                 0.972
# monthly_data_term_08                 0.980                 0.980
# monthly_data_term_09                 0.986                 0.985
# monthly_data_term_10                 0.990                 0.990
# monthly_data_term_11                 0.993                 0.993
# monthly_data_term_12                 0.995                 0.995
# monthly_data_term_13                 0.996                 0.996
# monthly_data_term_14                 0.998                 0.997
# monthly_data_term_15                 0.998                 0.998
# monthly_data_term_16                 0.999                 0.998
# monthly_data_term_17                 0.999                 0.999
# monthly_data_term_18                 0.999                 0.999
# monthly_data_term_19                 1.000                 0.999
# monthly_data_term_20                 1.000                 1.000
# monthly_data_term_21                 1.000                 1.000
# monthly_data_term_22                 1.000                 1.000
# monthly_data_term_23                 1.000                 1.000
# monthly_data_term_24                 1.000                 1.000
# monthly_data_term_25                 1.000                 1.000
# monthly_data_term_26                 1.000                 1.000
# monthly_data_term_27                 0.999                 1.000
# monthly_data_term_28                 0.999                 0.999
# monthly_data_term_29                 0.999                 0.999
# monthly_data_term_30                 0.998                 0.999
#
#                       monthly_data_term_25  monthly_data_term_26  \
# monthly_data_term_01                 0.830                 0.831
# monthly_data_term_02                 0.873                 0.874
# monthly_data_term_03                 0.907                 0.907
# monthly_data_term_04                 0.931                 0.932
# monthly_data_term_05                 0.949                 0.949
# monthly_data_term_06                 0.962                 0.962
# monthly_data_term_07                 0.972                 0.972
# monthly_data_term_08                 0.980                 0.980
# monthly_data_term_09                 0.985                 0.985
# monthly_data_term_10                 0.989                 0.989
# monthly_data_term_11                 0.992                 0.992
# monthly_data_term_12                 0.994                 0.994
# monthly_data_term_13                 0.996                 0.995
# monthly_data_term_14                 0.997                 0.996
# monthly_data_term_15                 0.998                 0.997
# monthly_data_term_16                 0.998                 0.998
# monthly_data_term_17                 0.998                 0.998
# monthly_data_term_18                 0.999                 0.998
# monthly_data_term_19                 0.999                 0.999
# monthly_data_term_20                 0.999                 0.999
# monthly_data_term_21                 1.000                 0.999
# monthly_data_term_22                 1.000                 1.000
# monthly_data_term_23                 1.000                 1.000
# monthly_data_term_24                 1.000                 1.000
# monthly_data_term_25                 1.000                 1.000
# monthly_data_term_26                 1.000                 1.000
# monthly_data_term_27                 1.000                 1.000
# monthly_data_term_28                 1.000                 1.000
# monthly_data_term_29                 0.999                 1.000
# monthly_data_term_30                 0.999                 0.999
#
#                       monthly_data_term_27  monthly_data_term_28  \
# monthly_data_term_01                 0.831                 0.832
# monthly_data_term_02                 0.874                 0.875
# monthly_data_term_03                 0.908                 0.908
# monthly_data_term_04                 0.932                 0.932
# monthly_data_term_05                 0.950                 0.950
# monthly_data_term_06                 0.963                 0.963
# monthly_data_term_07                 0.972                 0.972
# monthly_data_term_08                 0.980                 0.980
# monthly_data_term_09                 0.985                 0.985
# monthly_data_term_10                 0.989                 0.989
# monthly_data_term_11                 0.992                 0.991
# monthly_data_term_12                 0.994                 0.993
# monthly_data_term_13                 0.995                 0.994
# monthly_data_term_14                 0.996                 0.995
# monthly_data_term_15                 0.997                 0.996
# monthly_data_term_16                 0.997                 0.997
# monthly_data_term_17                 0.998                 0.997
# monthly_data_term_18                 0.998                 0.997
# monthly_data_term_19                 0.998                 0.998
# monthly_data_term_20                 0.999                 0.998
# monthly_data_term_21                 0.999                 0.998
# monthly_data_term_22                 0.999                 0.999
# monthly_data_term_23                 0.999                 0.999
# monthly_data_term_24                 1.000                 0.999
# monthly_data_term_25                 1.000                 1.000
# monthly_data_term_26                 1.000                 1.000
# monthly_data_term_27                 1.000                 1.000
# monthly_data_term_28                 1.000                 1.000
# monthly_data_term_29                 1.000                 1.000
# monthly_data_term_30                 1.000                 1.000
#
#                       monthly_data_term_29  monthly_data_term_30
# monthly_data_term_01                 0.832                 0.833
# monthly_data_term_02                 0.875                 0.876
# monthly_data_term_03                 0.909                 0.909
# monthly_data_term_04                 0.933                 0.933
# monthly_data_term_05                 0.950                 0.950
# monthly_data_term_06                 0.963                 0.963
# monthly_data_term_07                 0.972                 0.973
# monthly_data_term_08                 0.980                 0.979
# monthly_data_term_09                 0.985                 0.984
# monthly_data_term_10                 0.988                 0.988
# monthly_data_term_11                 0.991                 0.990
# monthly_data_term_12                 0.993                 0.992
# monthly_data_term_13                 0.994                 0.993
# monthly_data_term_14                 0.995                 0.994
# monthly_data_term_15                 0.995                 0.995
# monthly_data_term_16                 0.996                 0.995
# monthly_data_term_17                 0.996                 0.996
# monthly_data_term_18                 0.997                 0.996
# monthly_data_term_19                 0.997                 0.996
# monthly_data_term_20                 0.998                 0.997
# monthly_data_term_21                 0.998                 0.997
# monthly_data_term_22                 0.998                 0.998
# monthly_data_term_23                 0.999                 0.998
# monthly_data_term_24                 0.999                 0.999
# monthly_data_term_25                 0.999                 0.999
# monthly_data_term_26                 1.000                 0.999
# monthly_data_term_27                 1.000                 1.000
# monthly_data_term_28                 1.000                 1.000
# monthly_data_term_29                 1.000                 1.000
# monthly_data_term_30                 1.000                 1.000
#
# [30 rows x 30 columns]

# %%
#STATIONARITY TEST


def adf_test_all_to_table(df, freq_label):
    results = []
    terms = [col for col in df.columns if col.startswith(f'{freq_label}_data_term_')]
    
    for term in sorted(terms):
        series = df[term].dropna()
        result = adfuller(series)
        p_value = result[1]
        is_stationary = 'Yes' if p_value < 0.05 else 'No'

        maturity_num = int(re.search(r'_(\d+)$', term).group(1))

        results.append({
            'Maturity': maturity_num,
            'ADF Statistic': round(result[0], 4),
            'p-value': round(p_value, 4),
            'Stationary': is_stationary
        })
    
    df_results = pd.DataFrame(results)
    df_results = df_results.sort_values('Maturity').reset_index(drop=True)
    return df_results

# Maak de tabellen
daily_adf_results = adf_test_all_to_table(daily_df, 'daily')
monthly_adf_results = adf_test_all_to_table(monthly_df, 'monthly')

# Exporteer naar Excel (in dezelfde map waar je script draait)
daily_adf_results.to_excel('daily_adf_results.xlsx', index=False)
monthly_adf_results.to_excel('monthly_adf_results.xlsx', index=False)

print("Export complete! Je vindt de bestanden 'daily_adf_results.xlsx' en 'monthly_adf_results.xlsx' in je werkmap.")
# Out:
# Export complete! Je vindt de bestanden 'daily_adf_results.xlsx' en 'monthly_adf_results.xlsx' in je werkmap.
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\1597246384.py:32: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   daily_adf_results.to_excel('daily_adf_results.xlsx', index=False)
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\1597246384.py:33: UserWarning: Pandas requires version '3.0.5' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   monthly_adf_results.to_excel('monthly_adf_results.xlsx', index=False)

# %%
#MISSING DATA OVER TIME ANALYSES

# Voeg 'year' toe aan daily_df en monthly_df
daily_df['year'] = daily_df['years'].dt.year
monthly_df['year'] = monthly_df['years'].dt.year

# Groepeer per jaar en bereken % missing per maturiteit (kolom)
missing_per_year_daily = daily_df.groupby('year').apply(lambda x: x.isna().mean() * 100)
missing_per_year_monthly = monthly_df.groupby('year').apply(lambda x: x.isna().mean() * 100)

# Gemiddelde % missing over alle looptijden per jaar
avg_missing_per_year_daily = missing_per_year_daily.mean(axis=1)
avg_missing_per_year_monthly = missing_per_year_monthly.mean(axis=1)

print("\nAverage missing % per year - Daily:")
print(avg_missing_per_year_daily)

print("\nAverage missing % per year - Monthly:")
print(avg_missing_per_year_monthly)

# Plot
avg_missing_per_year_daily.plot(kind='bar', figsize=(10,5))
plt.ylabel('Average % Missing')
plt.title('Average Missing Data % per Year - Daily Data')
plt.show()

avg_missing_per_year_monthly.plot(kind='bar', figsize=(10,5))
plt.ylabel('Average % Missing')
plt.title('Average Missing Data % per Year - Monthly Data')
plt.show()
# Out:
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\3234682566.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_per_year_daily = daily_df.groupby('year').apply(lambda x: x.isna().mean() * 100)
# C:\Users\MK699GC\AppData\Local\Temp\ipykernel_40340\3234682566.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_per_year_monthly = monthly_df.groupby('year').apply(lambda x: x.isna().mean() * 100)
# Average missing % per year - Daily:
# year
# 1997.0    52.900327
# 1998.0    50.770548
# 1999.0    50.428082
# 2000.0    41.325137
# 2001.0    28.767123
# 2002.0    28.767123
# 2003.0    28.767123
# 2004.0    27.920082
# 2005.0    27.739726
# 2006.0    28.253425
# 2007.0    29.023973
# 2008.0    28.688525
# 2009.0    28.510274
# 2010.0    27.996575
# 2011.0    27.739726
# 2012.0    28.688525
# 2013.0    28.767123
# 2014.0    29.023973
# 2015.0    28.767123
# 2016.0    28.432377
# 2017.0    29.023973
# 2018.0    29.280822
# 2019.0    29.280822
# 2020.0    28.688525
# 2021.0    28.253425
# 2022.0    27.739726
# 2023.0    28.253425
# 2024.0    28.688525
# 2025.0    29.166667
# dtype: float64
#
# Average missing % per year - Monthly:
# year
# 1972    62.500000
# 1973    62.500000
# 1974    62.500000
# 1975    62.500000
# 1976    62.500000
# 1977    62.500000
# 1978    62.500000
# 1979    62.500000
# 1980    62.500000
# 1981    62.500000
# 1982    62.500000
# 1983    62.500000
# 1984    62.500000
# 1985    62.500000
# 1986    44.270833
# 1987    31.250000
# 1988    31.250000
# 1989    31.250000
# 1990    31.250000
# 1991    31.250000
# 1992    31.250000
# 1993    31.250000
# 1994    31.250000
# 1995    31.250000
# 1996    31.250000
# 1997    31.250000
# 1998    31.250000
# 1999    31.250000
# 2000     0.000000
# 2001     0.000000
# 2002     0.000000
# 2003     0.000000
# 2004     0.000000
# 2005     0.000000
# 2006     0.000000
# 2007     0.000000
# 2008     0.000000
# 2009     0.000000
# 2010     0.000000
# 2011     0.000000
# 2012     0.000000
# 2013     0.000000
# 2014     0.000000
# 2015     0.000000
# 2016     0.000000
# 2017     0.000000
# 2018     0.000000
# 2019     0.000000
# 2020     0.000000
# 2021     0.000000
# 2022     0.000000
# 2023     0.000000
# 2024     0.000000
# 2025     0.000000
# dtype: float64
